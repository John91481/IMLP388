# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ##  尋找matplotlib中可用字體
# 註：需知道中文字體的英文名稱

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['STIXSizeFourSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmtt10',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'cmr10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'cmmi10',
#  'STIXGeneral',
#  'cmss10',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'Franklin Gothic Medium',
#  'Microsoft YaHei',
#  'Courier New',
#  'Impact',
#  'MS Reference Specialty',
#  'Segoe UI',
#  'Book Antiqua',
#  'Lucida Handwriting',
#  'Bodoni MT',
#  'Gloucester MT Extra Condensed',
#  'Colonna MT',
#  'Freestyle Script',
#  'Segoe UI',
#  'Trebuchet MS',
#  'Curlz MT',
#  'Constantia',
#  'Corbel',
#  'Bahnschrift',
#  'Bell MT',
#  'Nirmala UI',
#  'Calibri',
#  'Franklin Gothic Demi',
#  'Lucida Calligraphy',
#  'Bodoni MT',
#  'Sitka Small',
#  'Century Gothic',
#  'Tw Cen MT',
#  'Felix Titling',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Garamond',
#  'Segoe UI',
#  'Goudy Old Style',
#  'Ebrima',
#  'Footlight MT Light',
#  'OCR A Extended',
#  'Calibri',
#  'MS Outlook',
#  'Cambria',
#  'Lucida Bright',
#  'Candara',
#  'Times New Roman',
#  'MS Gothic',
#  'Arial',
#  'Candara',
#  'MV Boli',
#  'Parchment',
#  'Lucida Sans Typewriter',
#  'Symbol',
#  'Niagara Engraved',
#  'Onyx',
#  'Elephant',
#  'Century Gothic',
#  'Perpetua',
#  'Georgia',
#  'Palatino Linotype',
#  'Arial',
#  'Ebrima',
#  'Niagara Solid',
#  'Lucida Sans Unicode',
#  'Palatino Linotype',
#  'Verdana',
#  'Arial',
#  'Gill Sans MT',
#  'Lucida Bright',
#  'Kunstler Script',
#  'Bodoni MT',
#  'Arial',
#  'Consolas',
#  'Maiandra GD',
#  'Pristina',
#  'Lucida Fax',
#  'Dubai',
#  'Georgia',
#  'Engravers MT',
#  'MingLiU-ExtB',
#  'Algerian',
#  'Comic Sans MS',
#  'Rockwell Extra Bold',
#  'Leelawadee UI',
#  'Berlin Sans FB',
#  'Script MT Bold',
#  'Mistral',
#  'Lucida Bright',
#  'Eras Bold ITC',
#  'Consolas',
#  'Imprint MT Shadow',
#  'Eras Demi ITC',
#  'Agency FB',
#  'Javanese Text',
#  'Lucida Fax',
#  'Microsoft Himalaya',
#  'Bodoni MT',
#  'Harrington',
#  'Courier New',
#  'Trebuchet MS',
#  'Calisto MT',
#  'Georgia',
#  'Gadugi',
#  'Tw Cen MT',
#  'Corbel',
#  'Arial Rounded MT Bold',
#  'Segoe UI',
#  'Calisto MT',
#  'Times New Roman',
#  'Malgun Gothic',
#  'Calibri',
#  'Arial',
#  'Gill Sans Ultra Bold',
#  'Candara',
#  'Franklin Gothic Demi',
#  'Lucida Sans',
#  'Goudy Old Style',
#  'Bell MT',
#  'Tw Cen MT Condensed Extra Bold',
#  'Arial',
#  'Segoe UI Historic',
#  'Franklin Gothic Heavy',
#  'Verdana',
#  'Kristen ITC',
#  'Segoe UI',
#  'Century Schoolbook',
#  'High Tower Text',
#  'Berlin Sans FB',
#  'Times New Roman',
#  'Segoe Script',
#  'Segoe UI',
#  'Lucida Sans Typewriter',
#  'Constantia',
#  'Gill Sans MT',
#  'HoloLens MDL2 Assets',
#  'Bodoni MT',
#  'Constantia',
#  'Rockwell',
#  'Centaur',
#  'Segoe UI',
#  'Malgun Gothic',
#  'Century Schoolbook',
#  'Rockwell',
#  'High Tower Text',
#  'Californian FB',
#  'Ink Free',
#  'Segoe Script',
#  'Californian FB',
#  'Rockwell Condensed',
#  'Bookman Old Style',
#  'MT Extra',
#  'Microsoft YaHei',
#  'Lucida Console',
#  'Comic Sans MS',
#  'Corbel',
#  'Century Gothic',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Corbel',
#  'Bookman Old Style',
#  'Eras Light ITC',
#  'Corbel',
#  'Microsoft PhagsPa',
#  'Leelawadee UI',
#  'Dubai',
#  'Gill Sans Ultra Bold Condensed',
#  'Perpetua',
#  'Franklin Gothic Book',
#  'Segoe Print',
#  'Century Gothic',
#  'Microsoft New Tai Lue',
#  'Comic Sans MS',
#  'Gigi',
#  'Magneto',
#  'Edwardian Script ITC',
#  'Consolas',
#  'Cambria',
#  'Gabriola',
#  'Bodoni MT',
#  'Microsoft Yi Baiti',
#  'SimSun-ExtB',
#  'Segoe Print',
#  'Garamond',
#  'Tahoma',
#  'Modern No. 20',
#  'Leelawadee',
#  'Tempus Sans ITC',
#  'Arial',
#  'Jokerman',
#  'Chiller',
#  'Poor Richard',
#  'Informal Roman',
#  'Wingdings 2',
#  'Papyrus',
#  'Lucida Fax',
#  'Dubai',
#  'MS Reference Sans Serif',
#  'Bodoni MT',
#  'Calibri',
#  'Segoe UI',
#  'Franklin Gothic Demi Cond',
#  'Cambria',
#  'MingLiU',
#  'Tw Cen MT',
#  'Gadugi',
#  'Lucida Sans',
#  'Lucida Sans Typewriter',
#  'Elephant',
#  'Calisto MT',
#  'Perpetua',
#  'Playbill',
#  'Rockwell',
#  'Forte',
#  'Book Antiqua',
#  'Perpetua Titling MT',
#  'Juice ITC',
#  'Comic Sans MS',
#  'Goudy Stout',
#  'Stencil',
#  'Broadway',
#  'Bradley Hand ITC',
#  'Arial',
#  'Lucida Sans',
#  'Courier New',
#  'Baskerville Old Face',
#  'Gill Sans MT',
#  'Brush Script MT',
#  'Calibri',
#  'Tw Cen MT Condensed',
#  'Wide Latin',
#  'Tw Cen MT',
#  'Cooper Black',
#  'Nirmala UI',
#  'Sitka Small',
#  'Goudy Old Style',
#  'Candara',
#  'Leelawadee UI',
#  'Constantia',
#  'Courier New',
#  'Candara',
#  'Trebuchet MS',
#  'Perpetua',
#  'Monotype Corsiva',
#  'Times New Roman',
#  'Bernard MT Condensed',
#  'Cambria',
#  'Verdana',
#  'Microsoft Uighur',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Mongolian Baiti',
#  'Rockwell Condensed',
#  'Haettenschweiler',
#  'Vladimir Script',
#  'Tahoma',
#  'Palatino Linotype',
#  'Bodoni MT',
#  'Microsoft Tai Le',
#  'Microsoft JhengHei',
#  'Berlin Sans FB Demi',
#  'Showcard Gothic',
#  'Lucida Sans',
#  'Viner Hand ITC',
#  'Segoe UI',
#  'Gill Sans MT',
#  'Calisto MT',
#  'Lucida Sans Typewriter',
#  'Microsoft JhengHei',
#  'Copperplate Gothic Bold',
#  'Dubai',
#  'Eras Medium ITC',
#  'Segoe UI',
#  'Century',
#  'Book Antiqua',
#  'Consolas',
#  'Yu Gothic',
#  'Century Schoolbook',
#  'Wingdings',
#  'Ravie',
#  'Rage Italic',
#  'Trebuchet MS',
#  'Corbel',
#  'Franklin Gothic Medium Cond',
#  'Segoe MDL2 Assets',
#  'Californian FB',
#  'Bauhaus 93',
#  'DFKai-SB',
#  'Tw Cen MT Condensed',
#  'Old English Text MT',
#  'Agency FB',
#  'Book Antiqua',
#  'Bookman Old Style',
#  'Lucida Bright',
#  'Blackadder ITC',
#  'SimSun',
#  'Garamond',
#  'Calibri',
#  'Georgia',
#  'Microsoft New Tai Lue',
#  'Palatino Linotype',
#  'Microsoft Uighur',
#  'Britannic Bold',
#  'Wingdings 3',
#  'Myanmar Text',
#  'Nirmala UI',
#  'Candara',
#  'Verdana',
#  'Microsoft PhagsPa',
#  'Microsoft YaHei',
#  'Yu Gothic',
#  'Yu Gothic',
#  'Sylfaen',
#  'Arial',
#  'Segoe UI',
#  'Segoe UI Emoji',
#  'Matura MT Script Capitals',
#  'Microsoft Tai Le',
#  'Bookshelf Symbol 7',
#  'Leelawadee',
#  'Gill Sans MT Condensed',
#  'Franklin Gothic Heavy',
#  'Bell MT',
#  'Copperplate Gothic Light',
#  'Webdings',
#  'Franklin Gothic Book',
#  'Microsoft Sans Serif',
#  'Castellar',
#  'Snap ITC',
#  'Gill Sans MT Ext Condensed Bold',
#  'French Script MT',
#  'Harlow Solid Italic',
#  'Sitka Small',
#  'Bodoni MT',
#  'Rockwell',
#  'Sitka Small',
#  'Segoe UI Symbol',
#  'Myanmar Text',
#  'Malgun Gothic',
#  'Franklin Gothic Medium',
#  'Vivaldi',
#  'Palace Script MT',
#  'Perpetua Titling MT',
#  'Bookman Old Style',
#  'Microsoft JhengHei']

# %%
'''
font_names = [f.name for f in fm.fontManager.ttflist]：這行程式碼使用了列表生成式（list comprehension）的方式，將所有可用的 TrueType 字型的名稱存儲在 font_names 變數中。

在這裡，fontManager.ttflist 是 font_manager 模組中的一個屬性，它返回一個包含所有可用 TrueType 字型的列表。接著，列表生成式 [f.name for f in fm.fontManager.ttflist] 遍歷這個列表，並對每個 TrueType 字型對象 f 取得其名稱 f.name
'''
# Out:
#   Cell In[12], line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# ## 測試中文字體Notes:
# ### Mac可用字體：SimHei
# ### Windows 7可用字體：Microsoft YaHei
# ### Windows 10 可用字體：Microsoft JhengHei、DFKai-SB

# %% [markdown]
# # 方法一：更改 plt.rcParams['font.sans-serif'] 設定
# ## Matplotlib example

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
#plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 

plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 

plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %% [markdown]
# ## Seaborn example

# %%
#from matplotlib.font_manager import FontProperties
import seaborn as sns
#sns.set(font=['sans-serif'])
#sns.set_style("whitegrid",{"font.sans-serif":['Microsoft JhengHei']})
cities_counter = [('好棒', 285), ('給我', 225), ('不要', 163), ('細柔', 136), ('吃飯', 130), ('小小', 124), ('深圳', 88), ('温州', 67), ('小知', 66), ('大之', 45)]
sns.set_color_codes("pastel")
sns.barplot(x=[k for k, _ in cities_counter[:10]], y=[v for _, v in cities_counter[:10]])

# %%
#from matplotlib.font_manager import FontProperties
import seaborn as sns
sns.set(font=['sans-serif'])
sns.set_style("whitegrid",{"font.sans-serif":['Microsoft JhengHei']})
cities_counter = [('好棒', 285), ('給我', 225), ('不要', 163), ('細柔', 136), ('吃飯', 130), ('小小', 124), ('深圳', 88), ('温州', 67), ('小知', 66), ('大之', 45)]
sns.set_color_codes("pastel")
sns.barplot(x=[k for k, _ in cities_counter[:10]], y=[v for _, v in cities_counter[:10]])

# %% [markdown]
# # 方法二：更改 plt.rcParams['font.family'] 設定

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(6,4))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='DFKai-SB' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %% [markdown]
# # 方法三：每次作圖使用特定字體

# %%
font1 = {'fontname':'SetoFont'}
font2 = {'fontname':'SimSun'}
font3 = {'fontname':'SimHei'}

plt.bar(x,y,align='center')
plt.title('瀨戶字體標題',**font1, fontsize=18) #標題名稱
plt.xlabel('新宋字體X軸',**font2, fontsize=18) #X軸名稱
plt.ylabel('黑體Y軸',**font3, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# # 方法四、自訂字體型式
# ### 下載`.ttf`字體檔，直接指定字體路徑

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='data/微軟正黑體.ttf')

plt.bar((1,2,3),(4,3,-1),align='center')
plt.title('微軟正黑體標題',fontproperties=font, fontsize=18) #標題名稱
plt.xlabel('微軟正黑體X軸',fontproperties=font, fontsize=18) #X軸名稱
plt.ylabel('微軟正黑體Y軸',fontproperties=font, fontsize=18) #Y軸名稱
plt.show()
